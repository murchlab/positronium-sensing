# %% [markdown]
# # Positronium Sensing: Reproducible Analysis
#
# This notebook is an entrypoint for the analysis workflow in this repository.
#
# ## Workflow
# Run the notebooks in `notebooks/` in numeric order:
#
# 1. [01_z_gate_curves_fig2cd.ipynb](notebooks/01_z_gate_curves_fig2cd.ipynb)
# 2. [02_ac_stark_shift_sweeps_fig2ef.ipynb](notebooks/02_ac_stark_shift_sweeps_fig2ef.ipynb)
# 3. [03_singlet_readout_corrected_fi_analysis.ipynb](notebooks/03_singlet_readout_corrected_fi_analysis.ipynb)
# 4. [04_singlet_raw_fi_analysis.ipynb](notebooks/04_singlet_raw_fi_analysis.ipynb)
# 5. [05_singlet_gate_corrected_fi_analysis.ipynb](notebooks/05_singlet_gate_corrected_fi_analysis.ipynb)
# 6. [06_combined_si_figures_and_fig3.ipynb](notebooks/06_combined_si_figures_and_fig3.ipynb)
# 7. [07_readout_integration_weights_demo.ipynb](notebooks/07_readout_integration_weights_demo.ipynb)
# 8. [08_readout_fidelity_correction_ibu_demo.ipynb](notebooks/08_readout_fidelity_correction_ibu_demo.ipynb)
#
# Optional:
# - [A01_integration_weights_demo_training_data.ipynb](notebooks/A01_integration_weights_demo_training_data.ipynb)
#
# ## Inputs and Outputs
# - Inputs: `data/` (see [data/README.md](data/README.md))
# - Derived data products: `data_analysis/` (see [data_analysis/README.md](data_analysis/README.md))
# - Figure exports: `si_figures/` (see [si_figures/README.md](si_figures/README.md))
