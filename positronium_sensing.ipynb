# %% [markdown]
# # Positronium Sensing: Reproducible Analysis
#
# This notebook is an entrypoint for the analysis workflow in this repository.
#
# ## Workflow
# Run the notebooks in `notebooks/` in numeric order:
#
# 1. [01_z_gates.ipynb](notebooks/01_z_gates.ipynb)
# 2. [02_ac_stark_shift.ipynb](notebooks/02_ac_stark_shift.ipynb)
# 3. [03_readout_fidelity_corrected_data.ipynb](notebooks/03_readout_fidelity_corrected_data.ipynb)
# 4. [04_raw_data.ipynb](notebooks/04_raw_data.ipynb)
# 5. [05_gate_fidelity_corrected_data.ipynb](notebooks/05_gate_fidelity_corrected_data.ipynb)
# 6. [06_combined_plots.ipynb](notebooks/06_combined_plots.ipynb)
# 7. [07_readout_integration_weights.ipynb](notebooks/07_readout_integration_weights.ipynb)
# 8. [08_readout_fidelity_correction.ipynb](notebooks/08_readout_fidelity_correction.ipynb)
#
# Optional:
# - [A01_integration_weights_training_set.ipynb](notebooks/A01_integration_weights_training_set.ipynb)
#
# ## Inputs and Outputs
# - Inputs: `data/` (see [data/README.md](data/README.md))
# - Derived data products: `data_analysis/` (see [data_analysis/README.md](data_analysis/README.md))
# - Figure exports: `si_figures/` (see [si_figures/README.md](si_figures/README.md))
