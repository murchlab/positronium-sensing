# %% [markdown]
# # Fisher information analysis

# %% [markdown]
# We extract the Fisher information from the experimental data by performing curve fitting.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
t_list_Uz = np.loadtxt(r'Data/singlet_Uz_t_list_1218.csv', delimiter=",", skiprows=1)
P_list_Uz = np.loadtxt(r'Data/singlet_Uz_P_1218.csv', delimiter=",", skiprows=1)

plt.plot(t_list_Uz, P_list_Uz[:, 1])
plt.ylim(0, 1)
plt.show()
